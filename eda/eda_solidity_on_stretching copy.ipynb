# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats import shapiro, kstest, boxcox
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Разведывательный анализ данных

# %% [markdown]
# ### Датасет для задачи на целевую переменную 'Прочность при растяжении' (solidity_on_stretching)

# %%
solidity_on_stretch_data = pd.read_csv('../data/data_processing/solidity_on_stretching.csv', sep=';', index_col=0)
solidity_on_stretch_data
# Out:
#       matrix_filler_ratio      density  elasticity    hardener     epoxid  \
# 0                1.857143  2030.000000  738.736842   30.000000  22.267857
# 1                1.857143  2030.000000  738.736842   50.000000  23.750000
# 2                1.857143  2030.000000  738.736842   49.900000  33.000000
# 3                1.857143  2030.000000  738.736842  129.000000  21.250000
# 4                2.771331  2030.000000  753.000000  111.860000  22.267857
# ...                   ...          ...         ...         ...        ...
# 1018             2.271346  1952.087902  912.855545   86.992183  20.123249
# 1019             3.444022  2050.089171  444.732634  145.981978  19.599769
# 1020             3.280604  1972.372865  416.836524  110.533477  23.957502
# 1021             3.705351  2066.799773  741.475517  141.397963  19.246945
# 1022             3.808020  1890.413468  417.316232  129.183416  27.474763
#
#       temperature  surface_density  solidity_on_stretching       resin  \
# 0      100.000000       210.000000             3000.000000  220.000000
# 1      284.615385       210.000000             3000.000000  220.000000
# 2      284.615385       210.000000             3000.000000  220.000000
# 3      300.000000       210.000000             3000.000000  220.000000
# 4      284.615385       210.000000             3000.000000  220.000000
# ...           ...              ...                     ...         ...
# 1018   324.774576       209.198700             2387.292495  125.007669
# 1019   254.215401       350.660830             2360.392784  117.730099
# 1020   248.423047       740.142791             2662.906040  236.606764
# 1021   275.779840       641.468152             2071.715856  197.126067
# 1022   300.952708       758.747882             2856.328932  194.754342
#
#       cover_angle  cover_step  cover_strength
# 0               0    4.000000       57.000000
# 1               0    4.000000       60.000000
# 2               0    4.000000       70.000000
# 3               0    5.000000       47.000000
# 4               0    5.000000       57.000000
# ...           ...         ...             ...
# 1018            1    9.076380       47.019770
# 1019            1   10.565614       53.750790
# 1020            1    4.161154       67.629684
# 1021            1    6.313201       58.261074
# 1022            1    6.078902       77.434468
#
# [1023 rows x 12 columns]

# %% [markdown]
# ### Первые 22 записи вызывают сомения из-за  целых значений ряда показателей - density, surface_density, elasticity_on_stretching, resine.
# ### Такие целые значения по этим переменным сильно выделяются на фоне остальных наблюдений.
# ### Есть предположение, что это 'грубый' ручной ввод данных, поэтому избавляемся от этих записей (наблюдений) без каких-либо значимых негативных последствий, т.к. всё ещё остаётся большое количество наблюдений.

# %%
def highlighter_for_many(cell_value, values_to_highlight=[]):
    if cell_value in values_to_highlight:
        return 'background-color: red; color: white;'
    

def highlighter_for_cell(x, row_idx, col_idx):
    color = 'background-color: red; color: white;'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    df_styler.iloc[row_idx, col_idx] = color
    return df_styler

# %%
values_to_highlight_1 = [21.25, 3000, 1800, 2000, 2100, 1900, 1930, 2030, 1990, 1950, 1980, 1910, 2000, 2160, 1880, 1890, 1920, 30, 50, 129, 300, 210, 380, 1010, 220, 120, 470, 70, 75, 78]
solidity_on_stretch_data.drop(columns=['cover_strength']).head(40).style.applymap(highlighter_for_many, values_to_highlight=values_to_highlight_1)
# Out:
# <style type="text/css">
# #T_569d6_row0_col1, #T_569d6_row0_col3, #T_569d6_row0_col6, #T_569d6_row0_col7, #T_569d6_row0_col8, #T_569d6_row1_col1, #T_569d6_row1_col3, #T_569d6_row1_col6, #T_569d6_row1_col7, #T_569d6_row1_col8, #T_569d6_row2_col1, #T_569d6_row2_col6, #T_569d6_row2_col7, #T_569d6_row2_col8, #T_569d6_row3_col1, #T_569d6_row3_col3, #T_569d6_row3_col4, #T_569d6_row3_col5, #T_569d6_row3_col6, #T_569d6_row3_col7, #T_569d6_row3_col8, #T_569d6_row4_col1, #T_569d6_row4_col6, #T_569d6_row4_col7, #T_569d6_row4_col8, #T_569d6_row5_col1, #T_569d6_row5_col6, #T_569d6_row5_col7, #T_569d6_row5_col8, #T_569d6_row6_col1, #T_569d6_row6_col6, #T_569d6_row6_col7, #T_569d6_row6_col8, #T_569d6_row7_col1, #T_569d6_row7_col6, #T_569d6_row7_col7, #T_569d6_row7_col8, #T_569d6_row8_col1, #T_569d6_row8_col3, #T_569d6_row8_col4, #T_569d6_row8_col5, #T_569d6_row8_col6, #T_569d6_row8_col7, #T_569d6_row8_col8, #T_569d6_row9_col1, #T_569d6_row9_col3, #T_569d6_row9_col4, #T_569d6_row9_col5, #T_569d6_row9_col6, #T_569d6_row9_col7, #T_569d6_row9_col8, #T_569d6_row10_col1, #T_569d6_row10_col3, #T_569d6_row10_col4, #T_569d6_row10_col5, #T_569d6_row10_col6, #T_569d6_row10_col7, #T_569d6_row10_col8, #T_569d6_row11_col1, #T_569d6_row11_col3, #T_569d6_row11_col4, #T_569d6_row11_col5, #T_569d6_row11_col6, #T_569d6_row11_col7, #T_569d6_row11_col8, #T_569d6_row12_col1, #T_569d6_row12_col3, #T_569d6_row12_col4, #T_569d6_row12_col5, #T_569d6_row12_col6, #T_569d6_row12_col8, #T_569d6_row13_col1, #T_569d6_row13_col3, #T_569d6_row13_col4, #T_569d6_row13_col5, #T_569d6_row13_col6, #T_569d6_row13_col8, #T_569d6_row14_col1, #T_569d6_row14_col3, #T_569d6_row14_col4, #T_569d6_row14_col5, #T_569d6_row14_col6, #T_569d6_row14_col8, #T_569d6_row15_col1, #T_569d6_row15_col3, #T_569d6_row15_col4, #T_569d6_row15_col5, #T_569d6_row15_col6, #T_569d6_row15_col7, #T_569d6_row15_col8, #T_569d6_row16_col1, #T_569d6_row16_col3, #T_569d6_row16_col4, #T_569d6_row16_col5, #T_569d6_row16_col6, #T_569d6_row16_col7, #T_569d6_row16_col8, #T_569d6_row17_col1, #T_569d6_row17_col3, #T_569d6_row17_col4, #T_569d6_row17_col5, #T_569d6_row17_col6, #T_569d6_row17_col7, #T_569d6_row17_col8, #T_569d6_row18_col1, #T_569d6_row18_col3, #T_569d6_row18_col4, #T_569d6_row18_col5, #T_569d6_row18_col6, #T_569d6_row18_col7, #T_569d6_row18_col8, #T_569d6_row19_col1, #T_569d6_row19_col6, #T_569d6_row19_col7, #T_569d6_row19_col8, #T_569d6_row20_col1, #T_569d6_row20_col6, #T_569d6_row20_col7, #T_569d6_row20_col8, #T_569d6_row21_col1, #T_569d6_row21_col6, #T_569d6_row21_col8, #T_569d6_row22_col1, #T_569d6_row22_col6, #T_569d6_row22_col8 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_569d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_569d6_level0_col0" class="col_heading level0 col0" >matrix_filler_ratio</th>
#       <th id="T_569d6_level0_col1" class="col_heading level0 col1" >density</th>
#       <th id="T_569d6_level0_col2" class="col_heading level0 col2" >elasticity</th>
#       <th id="T_569d6_level0_col3" class="col_heading level0 col3" >hardener</th>
#       <th id="T_569d6_level0_col4" class="col_heading level0 col4" >epoxid</th>
#       <th id="T_569d6_level0_col5" class="col_heading level0 col5" >temperature</th>
#       <th id="T_569d6_level0_col6" class="col_heading level0 col6" >surface_density</th>
#       <th id="T_569d6_level0_col7" class="col_heading level0 col7" >solidity_on_stretching</th>
#       <th id="T_569d6_level0_col8" class="col_heading level0 col8" >resin</th>
#       <th id="T_569d6_level0_col9" class="col_heading level0 col9" >cover_angle</th>
#       <th id="T_569d6_level0_col10" class="col_heading level0 col10" >cover_step</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_569d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_569d6_row0_col0" class="data row0 col0" >1.857143</td>
#       <td id="T_569d6_row0_col1" class="data row0 col1" >2030.000000</td>
#       <td id="T_569d6_row0_col2" class="data row0 col2" >738.736842</td>
#       <td id="T_569d6_row0_col3" class="data row0 col3" >30.000000</td>
#       <td id="T_569d6_row0_col4" class="data row0 col4" >22.267857</td>
#       <td id="T_569d6_row0_col5" class="data row0 col5" >100.000000</td>
#       <td id="T_569d6_row0_col6" class="data row0 col6" >210.000000</td>
#       <td id="T_569d6_row0_col7" class="data row0 col7" >3000.000000</td>
#       <td id="T_569d6_row0_col8" class="data row0 col8" >220.000000</td>
#       <td id="T_569d6_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_569d6_row0_col10" class="data row0 col10" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_569d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_569d6_row1_col0" class="data row1 col0" >1.857143</td>
#       <td id="T_569d6_row1_col1" class="data row1 col1" >2030.000000</td>
#       <td id="T_569d6_row1_col2" class="data row1 col2" >738.736842</td>
#       <td id="T_569d6_row1_col3" class="data row1 col3" >50.000000</td>
#       <td id="T_569d6_row1_col4" class="data row1 col4" >23.750000</td>
#       <td id="T_569d6_row1_col5" class="data row1 col5" >284.615385</td>
#       <td id="T_569d6_row1_col6" class="data row1 col6" >210.000000</td>
#       <td id="T_569d6_row1_col7" class="data row1 col7" >3000.000000</td>
#       <td id="T_569d6_row1_col8" class="data row1 col8" >220.000000</td>
#       <td id="T_569d6_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_569d6_row1_col10" class="data row1 col10" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_569d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_569d6_row2_col0" class="data row2 col0" >1.857143</td>
#       <td id="T_569d6_row2_col1" class="data row2 col1" >2030.000000</td>
#       <td id="T_569d6_row2_col2" class="data row2 col2" >738.736842</td>
#       <td id="T_569d6_row2_col3" class="data row2 col3" >49.900000</td>
#       <td id="T_569d6_row2_col4" class="data row2 col4" >33.000000</td>
#       <td id="T_569d6_row2_col5" class="data row2 col5" >284.615385</td>
#       <td id="T_569d6_row2_col6" class="data row2 col6" >210.000000</td>
#       <td id="T_569d6_row2_col7" class="data row2 col7" >3000.000000</td>
#       <td id="T_569d6_row2_col8" class="data row2 col8" >220.000000</td>
#       <td id="T_569d6_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_569d6_row2_col10" class="data row2 col10" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_569d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_569d6_row3_col0" class="data row3 col0" >1.857143</td>
#       <td id="T_569d6_row3_col1" class="data row3 col1" >2030.000000</td>
#       <td id="T_569d6_row3_col2" class="data row3 col2" >738.736842</td>
#       <td id="T_569d6_row3_col3" class="data row3 col3" >129.000000</td>
#       <td id="T_569d6_row3_col4" class="data row3 col4" >21.250000</td>
#       <td id="T_569d6_row3_col5" class="data row3 col5" >300.000000</td>
#       <td id="T_569d6_row3_col6" class="data row3 col6" >210.000000</td>
#       <td id="T_569d6_row3_col7" class="data row3 col7" >3000.000000</td>
#       <td id="T_569d6_row3_col8" class="data row3 col8" >220.000000</td>
#       <td id="T_569d6_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_569d6_row3_col10" class="data row3 col10" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_569d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_569d6_row4_col0" class="data row4 col0" >2.771331</td>
#       <td id="T_569d6_row4_col1" class="data row4 col1" >2030.000000</td>
#       <td id="T_569d6_row4_col2" class="data row4 col2" >753.000000</td>
#       <td id="T_569d6_row4_col3" class="data row4 col3" >111.860000</td>
#       <td id="T_569d6_row4_col4" class="data row4 col4" >22.267857</td>
#       <td id="T_569d6_row4_col5" class="data row4 col5" >284.615385</td>
#       <td id="T_569d6_row4_col6" class="data row4 col6" >210.000000</td>
#       <td id="T_569d6_row4_col7" class="data row4 col7" >3000.000000</td>
#       <td id="T_569d6_row4_col8" class="data row4 col8" >220.000000</td>
#       <td

# %% [markdown]
# ### И ещё вызывает подозрение единственное нулевое значение признака cover_strength ('Плотность нашивки') - лучше от него тоже избавиться.
# ### Но эта позиция и так попадат под удаление - находится среди Top22 строк на удаление.

# %%
solidity_on_stretch_data.head(30).style.apply(highlighter_for_cell, row_idx=19, col_idx=11, axis = None)
# Out:
# <style type="text/css">
# #T_f6334_row19_col11 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_f6334">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6334_level0_col0" class="col_heading level0 col0" >matrix_filler_ratio</th>
#       <th id="T_f6334_level0_col1" class="col_heading level0 col1" >density</th>
#       <th id="T_f6334_level0_col2" class="col_heading level0 col2" >elasticity</th>
#       <th id="T_f6334_level0_col3" class="col_heading level0 col3" >hardener</th>
#       <th id="T_f6334_level0_col4" class="col_heading level0 col4" >epoxid</th>
#       <th id="T_f6334_level0_col5" class="col_heading level0 col5" >temperature</th>
#       <th id="T_f6334_level0_col6" class="col_heading level0 col6" >surface_density</th>
#       <th id="T_f6334_level0_col7" class="col_heading level0 col7" >solidity_on_stretching</th>
#       <th id="T_f6334_level0_col8" class="col_heading level0 col8" >resin</th>
#       <th id="T_f6334_level0_col9" class="col_heading level0 col9" >cover_angle</th>
#       <th id="T_f6334_level0_col10" class="col_heading level0 col10" >cover_step</th>
#       <th id="T_f6334_level0_col11" class="col_heading level0 col11" >cover_strength</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6334_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6334_row0_col0" class="data row0 col0" >1.857143</td>
#       <td id="T_f6334_row0_col1" class="data row0 col1" >2030.000000</td>
#       <td id="T_f6334_row0_col2" class="data row0 col2" >738.736842</td>
#       <td id="T_f6334_row0_col3" class="data row0 col3" >30.000000</td>
#       <td id="T_f6334_row0_col4" class="data row0 col4" >22.267857</td>
#       <td id="T_f6334_row0_col5" class="data row0 col5" >100.000000</td>
#       <td id="T_f6334_row0_col6" class="data row0 col6" >210.000000</td>
#       <td id="T_f6334_row0_col7" class="data row0 col7" >3000.000000</td>
#       <td id="T_f6334_row0_col8" class="data row0 col8" >220.000000</td>
#       <td id="T_f6334_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_f6334_row0_col10" class="data row0 col10" >4.000000</td>
#       <td id="T_f6334_row0_col11" class="data row0 col11" >57.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6334_row1_col0" class="data row1 col0" >1.857143</td>
#       <td id="T_f6334_row1_col1" class="data row1 col1" >2030.000000</td>
#       <td id="T_f6334_row1_col2" class="data row1 col2" >738.736842</td>
#       <td id="T_f6334_row1_col3" class="data row1 col3" >50.000000</td>
#       <td id="T_f6334_row1_col4" class="data row1 col4" >23.750000</td>
#       <td id="T_f6334_row1_col5" class="data row1 col5" >284.615385</td>
#       <td id="T_f6334_row1_col6" class="data row1 col6" >210.000000</td>
#       <td id="T_f6334_row1_col7" class="data row1 col7" >3000.000000</td>
#       <td id="T_f6334_row1_col8" class="data row1 col8" >220.000000</td>
#       <td id="T_f6334_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_f6334_row1_col10" class="data row1 col10" >4.000000</td>
#       <td id="T_f6334_row1_col11" class="data row1 col11" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6334_row2_col0" class="data row2 col0" >1.857143</td>
#       <td id="T_f6334_row2_col1" class="data row2 col1" >2030.000000</td>
#       <td id="T_f6334_row2_col2" class="data row2 col2" >738.736842</td>
#       <td id="T_f6334_row2_col3" class="data row2 col3" >49.900000</td>
#       <td id="T_f6334_row2_col4" class="data row2 col4" >33.000000</td>
#       <td id="T_f6334_row2_col5" class="data row2 col5" >284.615385</td>
#       <td id="T_f6334_row2_col6" class="data row2 col6" >210.000000</td>
#       <td id="T_f6334_row2_col7" class="data row2 col7" >3000.000000</td>
#       <td id="T_f6334_row2_col8" class="data row2 col8" >220.000000</td>
#       <td id="T_f6334_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_f6334_row2_col10" class="data row2 col10" >4.000000</td>
#       <td id="T_f6334_row2_col11" class="data row2 col11" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6334_row3_col0" class="data row3 col0" >1.857143</td>
#       <td id="T_f6334_row3_col1" class="data row3 col1" >2030.000000</td>
#       <td id="T_f6334_row3_col2" class="data row3 col2" >738.736842</td>
#       <td id="T_f6334_row3_col3" class="data row3 col3" >129.000000</td>
#       <td id="T_f6334_row3_col4" class="data row3 col4" >21.250000</td>
#       <td id="T_f6334_row3_col5" class="data row3 col5" >300.000000</td>
#       <td id="T_f6334_row3_col6" class="data row3 col6" >210.000000</td>
#       <td id="T_f6334_row3_col7" class="data row3 col7" >3000.000000</td>
#       <td id="T_f6334_row3_col8" class="data row3 col8" >220.000000</td>
#       <td id="T_f6334_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_f6334_row3_col10" class="data row3 col10" >5.000000</td>
#       <td id="T_f6334_row3_col11" class="data row3 col11" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6334_row4_col0" class="data row4 col0" >2.771331</td>
#       <td id="T_f6334_row4_col1" class="data row4 col1" >2030.000000</td>
#       <td id="T_f6334_row4_col2" class="data row4 col2" >753.000000</td>
#       <td id="T_f6334_row4_col3" class="data row4 col3" >111.860000</td>
#       <td id="T_f6334_row4_col4" class="data row4 col4" >22.267857</td>
#       <td id="T_f6334_row4_col5" class="data row4 col5" >284.615385</td>
#       <td id="T_f6334_row4_col6" class="data row4 col6" >210.000000</td>
#       <td id="T_f6334_row4_col7" class="data row4 col7" >3000.000000</td>
#       <td id="T_f6334_row4_col8" class="data row4 col8" >220.000000</td>
#       <td id="T_f6334_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_f6334_row4_col10" class="data row4 col10" >5.000000</td>
#       <td id="T_f6334_row4_col11" class="data row4 col11" >57.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6334_row5_col0" class="data row5 col0" >2.767918</td>
#       <td id="T_f6334_row5_col1" class="data row5 col1" >2000.000000</td>
#       <td id="T_f6334_row5_col2" class="data row5 col2" >748.000000</td>
#       <td id="T_f6334_row5_col3" class="data row5 col3" >111.860000</td>
#       <td id="T_f6334_row5_col4" class="data row5 col4" >22.267857</td>
#       <td id="T_f6334_row5_col5" class="data row5 col5" >284.615385</td>
#       <td id="T_f6334_row5_col6" class="data row5 col6" >210.000000</td>
#       <td id="T_f6334_row5_col7" class="data row5 col7" >3000.000000</td>
#       <td id="T_f6334_row5_col8" class="data row5 col8" >220.000000</td>
#       <td id="T_f6334_row5_col9" class="data row5 col9" >0</td>
#       <td id="T_f6334_row5_col10" class="data row5 col10" >5.000000</td>
#       <td id="T_f6334_row5_col11" class="data row5 col11" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6334_row6_col0" class="data row6 col0" >2.569620</td>
#       <td id="T_f6334_row6_col1" class="data row6 col1" >1910.000000</td>
#       <td id="T_f6334_row6_col2" class="data row6 col2" >807.000000</td>
#       <td id="T_f6334_row6_col3" class="data row6 col3" >111.860000</td>
#       <td id="T_f6334_row6_col4" class="data row6 col4" >22.267857</td>
#       <td id="T_f6334_row6_col5" class="data row6 col5" >284.615385</td>
#       <td id="T_f6334_row6_col6" class="data row6 col6" >210.000000</td>
#       <td id="T_f6334_row6_col7" class="data row6 col7" >3000.000000</td>
#       <td id="T_f6334_row6_col8" class="data row6 col8" >220.000000</td>
#       <td id="T_f6334_row6_col9" class="data row6 col9" >0</td>
#       <td id="T_f6334_row6_col10" class="data row6 col10" >5.000000</td>
#       <td id="T_f6334_row6_col11" class="data row6 col11" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6334_l

# %%
solidity_on_stretch_data = solidity_on_stretch_data.loc[solidity_on_stretch_data.index[23:], :].reset_index(drop=True)
solidity_on_stretch_data
# Out:
#      matrix_filler_ratio      density   elasticity    hardener     epoxid  \
# 0               2.587348  1953.274926  1136.596135  137.627420  22.344534
# 1               2.499918  1942.595777   901.519947  146.252208  23.081757
# 2               2.046471  2037.631811   707.570887  101.617251  23.146393
# 3               1.856476  2018.220332   836.294382  135.401697  26.435515
# 4               3.305535  1917.907506   478.286247  105.786930  17.874100
# ..                   ...          ...          ...         ...        ...
# 995             2.271346  1952.087902   912.855545   86.992183  20.123249
# 996             3.444022  2050.089171   444.732634  145.981978  19.599769
# 997             3.280604  1972.372865   416.836524  110.533477  23.957502
# 998             3.705351  2066.799773   741.475517  141.397963  19.246945
# 999             3.808020  1890.413468   417.316232  129.183416  27.474763
#
#      temperature  surface_density  solidity_on_stretching       resin  \
# 0     234.716883       555.893453             2587.342983  246.613117
# 1     351.231874       864.725484             3705.672523  226.222760
# 2     312.307205       547.601219             2624.026407  178.198556
# 3     327.510377       150.961449             2473.187195  123.344561
# 4     328.154579       526.692159             3059.032991  275.575880
# ..           ...              ...                     ...         ...
# 995   324.774576       209.198700             2387.292495  125.007669
# 996   254.215401       350.660830             2360.392784  117.730099
# 997   248.423047       740.142791             2662.906040  236.606764
# 998   275.779840       641.468152             2071.715856  197.126067
# 999   300.952708       758.747882             2856.328932  194.754342
#
#      cover_angle  cover_step  cover_strength
# 0              1    4.000000       70.000000
# 1              1    5.000000       47.000000
# 2              1    5.000000       57.000000
# 3              1    5.000000       60.000000
# 4              1    5.000000       70.000000
# ..           ...         ...             ...
# 995            1    9.076380       47.019770
# 996            1   10.565614       53.750790
# 997            1    4.161154       67.629684
# 998            1    6.313201       58.261074
# 999            1    6.078902       77.434468
#
# [1000 rows x 12 columns]

# %%
solidity_on_stretch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   matrix_filler_ratio     1000 non-null   float64
#  1   density                 1000 non-null   float64
#  2   elasticity              1000 non-null   float64
#  3   hardener                1000 non-null   float64
#  4   epoxid                  1000 non-null   float64
#  5   temperature             1000 non-null   float64
#  6   surface_density         1000 non-null   float64
#  7   solidity_on_stretching  1000 non-null   float64
#  8   resin                   1000 non-null   float64
#  9   cover_angle             1000 non-null   int64
#  10  cover_step              1000 non-null   float64
#  11  cover_strength          1000 non-null   float64
# dtypes: float64(11), int64(1)
# memory usage: 93.9 KB

# %%
solidity_on_stretch_data.isna().sum()
# Out:
# matrix_filler_ratio       0
# density                   0
# elasticity                0
# hardener                  0
# epoxid                    0
# temperature               0
# surface_density           0
# solidity_on_stretching    0
# resin                     0
# cover_angle               0
# cover_step                0
# cover_strength            0
# dtype: int64

# %%
solidity_on_stretch_data.describe()
# Out:
#        matrix_filler_ratio      density   elasticity     hardener  \
# count          1000.000000  1000.000000  1000.000000  1000.000000
# mean              2.930612  1975.666791   739.950520   110.541116
# std               0.913939    73.796817   330.327013    28.304470
# min               0.389403  1731.764635     2.436909    17.740275
# 25%               2.318526  1924.203433   498.438068    92.170589
# 50%               2.907832  1977.574305   741.148111   110.162666
# 75%               3.552539  2021.159498   962.851423   130.311975
# max               5.591742  2207.773481  1911.536477   198.953207
#
#             epoxid  temperature  surface_density  solidity_on_stretching  \
# count  1000.000000  1000.000000      1000.000000             1000.000000
# mean     22.243850   285.911287       483.024665             2467.184290
# std       2.406999    40.962756       280.811736              485.624616
# min      14.254985   160.255843         0.603740             1036.856605
# 25%      20.558296   258.539199       268.057473             2143.834592
# 50%      22.230761   285.853960       452.972263             2461.249253
# 75%      23.982115   313.581449       694.210382             2760.163022
# max      28.955094   413.273418      1399.542362             3848.436732
#
#              resin  cover_angle   cover_step  cover_strength
# count  1000.000000   1000.00000  1000.000000     1000.000000
# mean    218.386876      0.50000     6.909904       57.181470
# std      59.819777      0.50025     2.560031       12.304355
# min      33.803026      0.00000     0.037639       11.740126
# 25%     179.190489      0.00000     5.116518       49.821889
# 50%     217.277006      0.50000     6.913444       57.362576
# 75%     257.495647      1.00000     8.585130       64.986942
# max     414.590628      1.00000    14.440522      103.988901

# %% [markdown]
# ### Для удобства переставим зависимую переменную elastisity_onstretching (Модуль упругости при растяжении) в первую колонку датасета.

# %%
first_col = solidity_on_stretch_data.pop('solidity_on_stretching')
solidity_on_stretch_data.insert(0, 'solidity_on_stretching', first_col)
solidity_on_stretch_data.head()
# Out:
#    solidity_on_stretching  matrix_filler_ratio      density   elasticity  \
# 0             2587.342983             2.587348  1953.274926  1136.596135
# 1             3705.672523             2.499918  1942.595777   901.519947
# 2             2624.026407             2.046471  2037.631811   707.570887
# 3             2473.187195             1.856476  2018.220332   836.294382
# 4             3059.032991             3.305535  1917.907506   478.286247
#
#      hardener     epoxid  temperature  surface_density       resin  \
# 0  137.627420  22.344534   234.716883       555.893453  246.613117
# 1  146.252208  23.081757   351.231874       864.725484  226.222760
# 2  101.617251  23.146393   312.307205       547.601219  178.198556
# 3  135.401697  26.435515   327.510377       150.961449  123.344561
# 4  105.786930  17.874100   328.154579       526.692159  275.575880
#
#    cover_angle  cover_step  cover_strength
# 0            1         4.0            70.0
# 1            1         5.0            47.0
# 2            1         5.0            57.0
# 3            1         5.0            60.0
# 4            1         5.0            70.0

# %% [markdown]
# ### Оценим парные диаграммы рассеяния данных.

# %%
sns.pairplot(data=solidity_on_stretch_data, x_vars=solidity_on_stretch_data.columns[1:], y_vars=solidity_on_stretch_data.columns[0]);

# %%
solidity_on_stretch_data.corrwith(solidity_on_stretch_data['solidity_on_stretching'])
# Out:
# solidity_on_stretching    1.000000
# matrix_filler_ratio       0.036288
# density                  -0.074165
# elasticity                0.048217
# hardener                 -0.066785
# epoxid                   -0.031613
# temperature              -0.026122
# surface_density           0.013333
# resin                     0.026477
# cover_angle               0.025412
# cover_step               -0.056045
# cover_strength            0.014987
# dtype: float64

# %% [markdown]
# ### Важно!
# ### Полностью отсутствует линейная взаимосвязь признаков с целевой переменной (elastisity_onstretching = Модуль упругости при растяжении). Корреляция - околонулевая.
# ### Похоже, перспективы получить качественную модель регрессии крайне малы.

# %%
sns.pairplot(data=solidity_on_stretch_data);

# %% [markdown]
# ### Явные связи между признаками также отсутствуют.
# ### Перспективы получить какие-то новые признаки через feature engineering, видимо, тоже невелики. Но можно попробовать (а) парное перемножение признаков и (б) получить новые признаки через PCA (главне компоненты).

# %% [markdown]
# ### Далее про наблюдения и данные...
# ### Практически все признаки (то же касается и целевой переменной) имеют форму распределения очень близкую к нормальному, что хорошо.
# ### Но есть некоторые признаки, над которыми можно поработать для улучшения формы их распределения.

# %%
# Проверка на нормальность распределения
# Shapiro-Wilksays H0 hypothesis is that data is normally distributed

for variable_name in solidity_on_stretch_data.columns.tolist():
    if variable_name != 'cover_angle':
        print(f'For {variable_name} Shapiro-Wilk test says: {"normal" if shapiro(solidity_on_stretch_data[variable_name].values)[1] > 0.05 else "not normal"}')    
        sm.qqplot(solidity_on_stretch_data[variable_name],  line='s', label=variable_name)
        plt.legend(frameon=False);
# Out:
# For solidity_on_stretching Shapiro-Wilk test says: normal
# For matrix_filler_ratio Shapiro-Wilk test says: normal
# For density Shapiro-Wilk test says: normal
# For elasticity Shapiro-Wilk test says: not normal
# For hardener Shapiro-Wilk test says: normal
# For epoxid Shapiro-Wilk test says: normal
# For temperature Shapiro-Wilk test says: normal
# For surface_density Shapiro-Wilk test says: not normal
# For resin Shapiro-Wilk test says: normal
# For cover_step Shapiro-Wilk test says: normal
# For cover_strength Shapiro-Wilk test says: not normal

# %% [markdown]
# ### Применяем boxcox трансформацию для признака 'elasticity' (модуль упругости)

# %%
fig, ax = plt.subplots(1, 4, figsize=(30, 6))
sns.histplot(solidity_on_stretch_data['elasticity'], ax=ax[0])
sm.qqplot(solidity_on_stretch_data['elasticity'], line='s', ax=ax[1])
sm.qqplot(boxcox(solidity_on_stretch_data['elasticity'])[0], line='s', ax=ax[2])
sns.histplot(boxcox(solidity_on_stretch_data['elasticity'])[0], ax=ax[3])
plt.show()

# %%
# Проверка на отсутствие негативных значений
solidity_on_stretch_data['elasticity'].min() , boxcox(solidity_on_stretch_data['elasticity'].values + 1)[0].min()
# Out:
# (2.4369087535075, 2.1857594002244976)

# %%
solidity_on_stretch_data['elasticity_boxcox'], elasticity_boxcox_lambda = boxcox(solidity_on_stretch_data['elasticity'].values + 1)

# %% [markdown]
# ### Применяем boxcox трансформацию для признака 'surface density' (поверхностная плотность)

# %%
fig, ax = plt.subplots(1, 4, figsize=(30, 6))
sns.histplot(solidity_on_stretch_data['surface_density'], ax=ax[0])
sm.qqplot(solidity_on_stretch_data['surface_density'], line='s', ax=ax[1])
sm.qqplot(boxcox(solidity_on_stretch_data['surface_density'])[0], line='s', ax=ax[2])
sns.histplot(boxcox(solidity_on_stretch_data['surface_density'])[0], ax=ax[3])
plt.show()

# %%
# Проверка на отсутствие негативных значений
solidity_on_stretch_data['surface_density'].min() , boxcox(solidity_on_stretch_data['surface_density'].values + 1)[0].min()
# Out:
# (0.603739925153945, 0.5508042842993189)

# %%
solidity_on_stretch_data['surface_density_boxcox'], surface_density_boxcox_lambda = boxcox(solidity_on_stretch_data['surface_density'].values + 1)

# %% [markdown]
# ### Применяем boxcox трансформацию для признака 'cover strength' (плотность нашивки)

# %%
fig, ax = plt.subplots(1, 4, figsize=(30, 6))
sns.histplot(solidity_on_stretch_data['cover_strength'], ax=ax[0])
sm.qqplot(solidity_on_stretch_data['cover_strength'], line='s', ax=ax[1])
sm.qqplot(boxcox(solidity_on_stretch_data['cover_strength'] + 0.001)[0], line='s', ax=ax[2])
sns.histplot(boxcox(solidity_on_stretch_data['cover_strength'] + 0.001)[0], ax=ax[3])
plt.show()

# %%
# Проверка на отсутствие негативных значений
solidity_on_stretch_data['cover_strength'].min() , boxcox(solidity_on_stretch_data['cover_strength'].values + 1)[0].min()
# Out:
# (11.7401256604075, 17.31381736884777)

# %%
solidity_on_stretch_data['cover_strength_boxcox'], cover_strength_boxcox_lambda = boxcox(solidity_on_stretch_data['cover_strength'].values + 1)

# %%
# Удаляем из датасета исходные значения признаков, которые трансформировали черех boxcox преобразование
solidity_on_stretch_data = solidity_on_stretch_data.drop(columns=['elasticity', 'surface_density', 'cover_strength'])
solidity_on_stretch_data.head()
# Out:
#    solidity_on_stretching  matrix_filler_ratio      density    hardener  \
# 0             2587.342983             2.587348  1953.274926  137.627420
# 1             3705.672523             2.499918  1942.595777  146.252208
# 2             2624.026407             2.046471  2037.631811  101.617251
# 3             2473.187195             1.856476  2018.220332  135.401697
# 4             3059.032991             3.305535  1917.907506  105.786930
#
#       epoxid  temperature       resin  cover_angle  cover_step  \
# 0  22.344534   234.716883  246.613117            1         4.0
# 1  23.081757   351.231874  226.222760            1         5.0
# 2  23.146393   312.307205  178.198556            1         5.0
# 3  26.435515   327.510377  123.344561            1         5.0
# 4  17.874100   328.154579  275.575880            1         5.0
#
#    elasticity_boxcox  surface_density_boxcox  cover_strength_boxcox
# 0         468.670776               85.631671             145.526898
# 1         384.618053              113.823065              90.114645
# 2         312.793361               84.805005             113.632918
# 3         360.746332               36.659075             120.868161
# 4         223.892990               82.700017             145.526898

# %% [markdown]
# ### Сохраняем значения BoxCox lambdas

# %%
solidity_strech_data_lambdas = {
    'elasticity_boxcox_lambda': elasticity_boxcox_lambda,
    'surface_density_boxcox_lambda': surface_density_boxcox_lambda,
    'cover_strength_boxcox_lambda': cover_strength_boxcox_lambda}

solidity_strech_data_lambdas
# Out:
# {'elasticity_boxcox_lambda': 0.8514864751506241,
#  'surface_density_boxcox_lambda': 0.6348829215273967,
#  'cover_strength_boxcox_lambda': 1.2154612257440889}

# %%
plt.figure(figsize=(25, 10))
sns.boxplot(solidity_on_stretch_data.drop(columns=['solidity_on_stretching', 'cover_angle', 'density']))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### В принципе, можно избавиться от выбросов

# %%
# Remove outliers

def compute_IQR_boundaries(data):
    IQR = data.quantile(0.75) - data.quantile(0.25)
    IQR_bound_lower = data.quantile(0.25) - 1.5 * IQR
    IQR_bound_upper = data.quantile(0.75) + 1.5 * IQR
    return (IQR_bound_lower, IQR_bound_upper)


def detect_outliers(data):
    IQR = data.quantile(0.75) - data.quantile(0.25)
    IQR_bound_lower = data.quantile(0.25) - 1.5 * IQR
    IQR_bound_upper = data.quantile(0.75) + 1.5 * IQR
    res = [x if (x >= IQR_bound_lower) & (x <= IQR_bound_upper) else np.nan for x in data]
    return res

# %%
solidity_on_stretch_data = pd.DataFrame(solidity_on_stretch_data.apply(detect_outliers, axis=0)).dropna().reset_index(drop=True)
solidity_on_stretch_data
# Out:
#      solidity_on_stretching  matrix_filler_ratio      density    hardener  \
# 0               2587.342983             2.587348  1953.274926  137.627420
# 1               2624.026407             2.046471  2037.631811  101.617251
# 2               2473.187195             1.856476  2018.220332  135.401697
# 3               3059.032991             3.305535  1917.907506  105.786930
# 4               2288.967377             2.709554  1892.071124   96.563293
# ..                      ...                  ...          ...         ...
# 921             2387.292495             2.271346  1952.087902   86.992183
# 922             2360.392784             3.444022  2050.089171  145.981978
# 923             2662.906040             3.280604  1972.372865  110.533477
# 924             2071.715856             3.705351  2066.799773  141.397963
# 925             2856.328932             3.808020  1890.413468  129.183416
#
#         epoxid  temperature       resin  cover_angle  cover_step  \
# 0    22.344534   234.716883  246.613117            1    4.000000
# 1    23.146393   312.307205  178.198556            1    5.000000
# 2    26.435515   327.510377  123.344561            1    5.000000
# 3    17.874100   328.154579  275.575880            1    5.000000
# 4    22.989291   262.956722  126.816339            1    7.000000
# ..         ...          ...         ...          ...         ...
# 921  20.123249   324.774576  125.007669            1    9.076380
# 922  19.599769   254.215401  117.730099            1   10.565614
# 923  23.957502   248.423047  236.606764            1    4.161154
# 924  19.246945   275.779840  197.126067            1    6.313201
# 925  27.474763   300.952708  194.754342            1    6.078902
#
#      elasticity_boxcox  surface_density_boxcox  cover_strength_boxcox
# 0           468.670776               85.631671             145.526898
# 1           312.793361               84.805005             113.632918
# 2           360.746332               36.659075             120.868161
# 3           223.892990               82.700017             145.526898
# 4           287.514837              108.667505              90.114645
# ..                 ...                     ...                    ...
# 921         388.740128               45.403985              90.160173
# 922         210.404942               63.557294             105.887238
# 923         199.076146              102.983095             139.609893
# 924         325.540723               93.916114             116.664723
# 925         199.271889              104.641953             164.357714
#
# [926 rows x 12 columns]

# %%
plt.figure(figsize=(25, 10))
sns.boxplot(solidity_on_stretch_data.drop(columns=['solidity_on_stretching', 'cover_angle', 'density']))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Сохраняем финальный датасет для обучения моделей.

# %%
solidity_on_stretch_data.to_csv('../data/data_for_model/solidity_on_stretching_data_to_use.csv', sep=';', index=True)

# %% [markdown]
# # А что если ещё...

# %% [markdown]
# ### Если нет линейной зависимости (отсутствует корреляция) между целевой переменной и признаками, взятыми по-отдельности / по-одному (т.е. по вертикали = feature-wise), то, возможно, целевая переменная "реагирует" на набор признаков, как единое целое, как "рецепт"/состав композитного материала, т.е. важная взаимосвязь признаков между собой по горизонтали - по строкам (sample-wise).

# %% [markdown]
# ### Тогда можно предположить, что относительно схожим значениям целевой переменной (т.е. разница д.б. близка к 0 или около того) должны соответствовать оносительтно схожие по своему составу ("рецепту") испытываемые образцы композитных материалов.

# %% [markdown]
# ### Отсюда сделаем следующее упражнение... Попарно сравним все наблюдения (эксперименты) между собой на предмет схожести / разности через косинусное расстояние между векторами признаков и при этом будет фиксировать разницу между значениями целевой переменной сравниваемых векторов (= "рецептуры" композитных материалов).

# %%
solidity_on_stretch_data = pd.read_csv('../data/data_for_model/solidity_on_stretching_data_to_use.csv', sep=';', index_col=[0])

# %%
# Убираем категориальную переменную (она просто даёт би-модальное распределение) и нормализуем данные.
cover_angle = solidity_on_stretch_data.pop('cover_angle')
data_scaled = pd.DataFrame(MinMaxScaler().fit_transform(solidity_on_stretch_data), index=solidity_on_stretch_data.index, columns=solidity_on_stretch_data.columns)
# data_scaled = pd.concat([data_scaled, cover_angle], axis=1)
data_scaled
# Out:
#      solidity_on_stretching  matrix_filler_ratio   density  hardener  \
# 0                  0.554738             0.427955  0.447627  0.697727
# 1                  0.569959             0.314487  0.671337  0.451468
# 2                  0.507371             0.274628  0.619859  0.682506
# 3                  0.750455             0.578621  0.353835  0.479982
# 4                  0.430934             0.453592  0.285319  0.416906
# ..                      ...                  ...       ...       ...
# 921                0.471731             0.361662  0.444480  0.351453
# 922                0.460570             0.607674  0.704373  0.754860
# 923                0.586091             0.573391  0.498274  0.512442
# 924                0.340790             0.662497  0.748688  0.723512
# 925                0.666348             0.684036  0.280923  0.639982
#
#        epoxid  temperature     resin  cover_step  elasticity_boxcox  \
# 0    0.501436     0.267751  0.619323    0.289334           0.727020
# 1    0.561912     0.643139  0.387697    0.362355           0.484084
# 2    0.809975     0.716694  0.201982    0.362355           0.558819
# 3    0.164279     0.719810  0.717380    0.362355           0.345532
# 4    0.550063     0.404378  0.213737    0.508396           0.444688
# ..        ...          ...       ...         ...                ...
# 921  0.333908     0.703458  0.207613    0.660014           0.602448
# 922  0.294428     0.362087  0.182974    0.768759           0.324511
# 923  0.623085     0.334063  0.585446    0.301102           0.306855
# 924  0.267818     0.466417  0.451779    0.458245           0.503951
# 925  0.888354     0.588206  0.443749    0.441137           0.307160
#
#      surface_density_boxcox  cover_strength_boxcox
# 0                  0.550721               0.716005
# 1                  0.545370               0.495298
# 2                  0.233725               0.545366
# 3                  0.531744               0.716005
# 4                  0.699829               0.332551
# ..                      ...                    ...
# 921                0.290330               0.332866
# 922                0.407835               0.441698
# 923                0.663035               0.675059
# 924                0.604345               0.516278
# 925                0.673772               0.846315
#
# [926 rows x 11 columns]

# %%
similarity_res = []
used_rows = []

for i in data_scaled.index.tolist():
    used_rows.append(i)
    target_master = data_scaled.loc[i, data_scaled.columns.tolist()[0]] 
    array_master = np.expand_dims(data_scaled.loc[i, data_scaled.columns.tolist()[1:]].values, axis=0)
    subset = data_scaled.drop(index=i)
    for j in subset.index.tolist():
        if j not in used_rows:
            target_pair = subset.loc[j, subset.columns.tolist()[0]]
            array_pair = np.expand_dims(subset.loc[j, subset.columns.tolist()[1:]].values, axis=0)
            # target_diff = np.abs(target_master - target_pair)
            target_diff = target_master - target_pair
            cosin_sim = cosine_similarity(array_master, array_pair).ravel()[0]
            similarity_res.append((target_diff, cosin_sim))

# %%
similarity_df = pd.DataFrame(similarity_res, columns=['Target_diff', 'Cosine_sim'])
sns.jointplot(data=similarity_df, x='Cosine_sim', y='Target_diff', height=8)

# %%
np.corrcoef(similarity_df['Cosine_sim'], similarity_df['Target_diff'])[0][1]
# Out:
# -0.013726760694053868

# %% [markdown]
# ### Получается странная картина... чем менее схожи попарно между собой эксперименты по "рецептуре" (т.е. меньше косинусное расстояние), тем меньше разница в целевых переменных и наоборот - чем выше сходство (косинусное расстояние ближе к 1), тем больше разница между получаемыми значениями целевой переменной.

# %% [markdown]
# ### Вывод:
# ### Классическая регрессия, скорее всего, не сработает, в т.ч. разбиение на train-test. Возможно, более правильным (но в тоже время - ресурсоёмким) решением будет сравнение моделей через LeaveOneOut кросс-валидацию.
# ### Другой вариант - от задачи регресии перейти к задаче классификации, разбив целевую переменную на интервалы (bins) = классы, и каждый класс будет соответствовать среднему значению целевой переменной в заданном интервале.

# %%
# def assign_hist_bin_number(data, n_bins=10):
#     _, binEdges = np.histogram(data, bins=n_bins)
#     bin_numbers = [[i + 1  for i in np.arange(n_bins) if (x >= binEdges[i]) & (x <= binEdges[i + 1])] for x in data]
#     return bin_numbers

# %%
# bins = pd.DataFrame(data_elasticity.drop(columns=['cover_angle']).apply(assign_hist_bin_number, axis=0)).dropna().reset_index(drop=True).apply(lambda x: sum(x, []), axis=1).to_frame()
# bins = pd.DataFrame(data_elasticity.drop(columns=['cover_angle']).apply(assign_hist_bin_number, axis=0)).apply(lambda x: sum(x, []), axis=1).to_frame()
# bins_df = bins[0].apply(pd.Series)
# bins_df.columns = data_elasticity.drop(columns=['cover_angle']).columns
# bins_df

# %%
# bins_df.isna().sum()

# %%
# y_bin_labels = bins_df['elasticity_on_stretching'].unique().astype(int)
# y_bins_matched = {}
# y_bins_missmatched = {}

# for y_label in y_bin_labels:    
#     subset = bins_df.loc[bins_df['elasticity_on_stretching'] == y_label, bins_df.columns[1:]]    
#     for idx in subset.index:
#         row_main = subset.loc[idx, :].values
#         subset_2 = subset.drop(index=[idx])
#         for idx_2 in subset_2.index:
#             row_compare = subset_2.loc[idx_2, :].values
#             if np.sum(np.abs(np.subtract(row_main, row_compare))) == 0:
#                 y_bins_matched.setdefault(y_label, []).append((idx, idx_2))
#             else:
#                 y_bins_missmatched.setdefault(y_label, []).append((idx, idx_2))

# %%
# all_y_bins_matched = []
# all_y_bins_missmatched = []

# for idx in bins_df.index:
#     row_main = bins_df.loc[idx, :].values
#     subset = bins_df.drop(index=[idx])
#     for idx_2 in subset.index:
#         row_compare = subset.loc[idx_2, :].values
#         if np.sum(np.abs(np.subtract(row_main, row_compare))) == 0:
#             all_y_bins_matched.append((idx, idx_2))
#         else:
#             all_y_bins_missmatched.append((idx, idx_2))

# %%
# y_bins_matched

# %%
# y_bins_missmatched
